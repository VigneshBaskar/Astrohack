# %%
# %matplotlib inline

import sys
import os

sys.path.append("../Pre_processing")

from Data_Preparation_Library import *

maxBatchId = 1
selectedBatches=[str(i) for i in range(maxBatchId)]
batch_data_object = []
for i in selectedBatches:
    with open(os.path.join(temp_path,'full_data_object_' + i + '.p'), 'rb') as handle:
        batch_data_object+=pickle.load(handle)
# Out:
# Using TensorFlow backend.

# %%
batch_data_object[4].plot_image()

# %%
batch_data_object[0].g_image_resized.shape
# Out:
# (128, 128)

# %%
from skimage.exposure import equalize_hist

# %%
def get_front(image):
    front = image>=np.percentile(image, 50)

# %%
img = imgs[0]
img[img>=np.percentile(img,80)]
# Out:
# array([ 0.03987418,  0.07134619,  0.03897355, ...,  0.02333956,
#         0.01677459,  0.0744977 ])

# %%
plt.imshow(img>=np.percentile(img,90))

# %%
def get_g_Data_for_Autoencoder(data_object):
    X_list=[(data_object[index].g_image_resized)/data_object[index].g_image_resized.max() for index in range(len(data_object))]
    return np.asarray(X_list),np.asarray(X_list)

# %%
imgs=get_g_Data_for_Autoencoder(batch_data_object[4:5])[0]
plot_images(imgs)
plt.show()
plot_images([get_front(img) for img in imgs])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-8db821b001ae> in <module>()
#       2 plot_images(imgs)
#       3 plt.show()
# ----> 4 plot_images([get_front(img) for img in imgs])
#
# /vsc-hard-mounts/leuven-data/319/vsc31950/Astrohack_thomas/Code/Pre_processing/Data_Preparation_Library.py in plot_images(images)
#      49     for i,img in enumerate(images):
#      50         plt.subplot(1,len(images),i+1)
# ---> 51         img=plt.imshow(img)
#      52         img.set_cmap('hot')
#      53         plt.axis("off")
#
# /data/leuven/319/vsc31950/miniconda3/envs/keras/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3156                         filternorm=filternorm, filterrad=filterrad,
# ...
